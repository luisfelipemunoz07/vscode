# %%
import maptlotlib.pyplot as plt
casas = [1, 2, 3, 4, 5]
precios = [50000, 60000, 70000, 80000, 90000]
plt.plot(casas, precios)      
plt.xlabel('Numero de casas')
plt.ylabel('Precios en USD')                    
plt.show()
